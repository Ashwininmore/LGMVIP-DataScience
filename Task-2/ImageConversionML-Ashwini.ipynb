# %% [markdown]
# # Name - Ashwini Nitin More
# # Data Science Intern @ LetsGrowMore
#
# ## Task 2
# ## Beginner Level
# ## Name of Project : Image to Pencil SKetch with Python

# %% [markdown]
# # Importing The Libraries

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %% [markdown]
# # Read the Image

# %%
img = cv2.imread("bicycle.jpg")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=880x733 at 0x1B5476F4E08>

# %% [markdown]
# # Converting the Original Image into Grayscale

# %%
grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grayImg))
# Out:
# <PIL.Image.Image image mode=L size=880x733 at 0x1B550843248>

# %% [markdown]
# # Inverting the Grayscale Image

# %%
inv_grayImg = 255 - grayImg

# %%
inv_grayImg
# Out:
# array([[ 20,  19,  19, ...,  13,  14,  14],
#        [ 20,  20,  19, ...,  13,  14,  14],
#        [ 20,  20,  20, ...,  13,  13,  14],
#        ...,
#        [184, 184, 184, ..., 206, 206, 207],
#        [185, 185, 184, ..., 206, 206, 207],
#        [185, 185, 185, ..., 206, 206, 207]], dtype=uint8)

# %%
display(Image.fromarray(inv_grayImg))
# Out:
# <PIL.Image.Image image mode=L size=880x733 at 0x1B550843988>

# %% [markdown]
# # Blur the Image

# %%
blur_img = cv2.GaussianBlur(inv_grayImg, (35,35), 0)

# %%
display(Image.fromarray(blur_img))
# Out:
# <PIL.Image.Image image mode=L size=880x733 at 0x1B550852048>

# %% [markdown]
# # Mixing the grayscale image and inverted blur image

# %%
inv_blurImg = 255 - blur_img

# %%
inv_blurImg
# Out:
# array([[235, 235, 235, ..., 246, 246, 246],
#        [235, 235, 235, ..., 246, 246, 246],
#        [235, 235, 235, ..., 246, 246, 246],
#        ...,
#        [ 73,  73,  73, ...,  48,  48,  48],
#        [ 73,  73,  73, ...,  49,  49,  49],
#        [ 73,  73,  73, ...,  49,  49,  49]], dtype=uint8)

# %%
display(Image.fromarray(inv_blurImg))
# Out:
# <PIL.Image.Image image mode=L size=880x733 at 0x1B550907448>

# %%
def mix(grayImg, blur_img):
    return cv2.divide(grayImg, inv_blurImg, scale = 210.0)

# %%
pencil_sketch = mix(grayImg, inv_blurImg)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=880x733 at 0x1B55091BF88>

# %% [markdown]
# # Thank You!
